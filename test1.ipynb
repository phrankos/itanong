# %%
# %pip install langchain
# %pip install openai
# %pip install python-dotenv
# %pip install langchain-experimental
# Out:
# Requirement already satisfied: langchain in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (0.1.6)
# Requirement already satisfied: PyYAML>=5.3 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (0.6.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.18 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.22 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (0.1.23)
# Requirement already satisfied: langsmith<0.1,>=0.0.83 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.22->langchain) (4.4.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.22->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.22->langchain) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (1.30.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (1.10.13)
# Requirement already satisfied: sniffio in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from openai) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-experimental
#   Using cached langchain_experimental-0.0.59-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-community<0.3,>=0.2 (from langchain-experimental)
#   Using cached langchain_community-0.2.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting langchain-core<0.3,>=0.2 (from langchain-experimental)
#   Using cached langchain_core-0.2.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (0.6.6)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain-community<0.3,>=0.2->langchain-experimental)
#   Using cached langchain-0.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community<0.3,>=0.2->langchain-experimental)
#   Using cached langsmith-0.1.67-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-community<0.3,>=0.2->langchain-experimental) (8.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2->langchain-experimental) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2->langchain-experimental) (1.10.13)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3,>=0.2->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3,>=0.2->langchain-experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3,>=0.2->langchain-experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3,>=0.2->langchain-experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3,>=0.2->langchain-experimental) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2->langchain-experimental) (2.4)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain-community<0.3,>=0.2->langchain-experimental)
#   Using cached langchain_text_splitters-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3,>=0.2->langchain-experimental) (3.10.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.2->langchain-experimental) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.3,>=0.2->langchain-experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.3,>=0.2->langchain-experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.3,>=0.2->langchain-experimental) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.3,>=0.2->langchain-experimental) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3,>=0.2->langchain-experimental) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/theebatican/anaconda3/envs/itanong/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3,>=0.2->langchain-experimental) (1.0.0)
# Using cached langchain_experimental-0.0.59-py3-none-any.whl (199 kB)
# Using cached langchain_community-0.2.1-py3-none-any.whl (2.1 MB)
# Using cached langchain_core-0.2.3-py3-none-any.whl (310 kB)
# Using cached langchain-0.2.1-py3-none-any.whl (973 kB)
# Using cached langsmith-0.1.67-py3-none-any.whl (124 kB)
# Using cached langchain_text_splitters-0.2.0-py3-none-any.whl (23 kB)
# Installing collected packages: langsmith, langchain-core, langchain-text-splitters, langchain, langchain-community, langchain-experimental
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.87
#     Uninstalling langsmith-0.0.87:
#       Successfully uninstalled langsmith-0.0.87
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.23
#     Uninstalling langchain-core-0.1.23:
#       Successfully uninstalled langchain-core-0.1.23
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.6
#     Uninstalling langchain-0.1.6:
#       Successfully uninstalled langchain-0.1.6
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.20
#     Uninstalling langchain-community-0.0.20:
#       Successfully uninstalled langchain-community-0.0.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.0.6 requires langchain-core<0.2,>=0.1.16, but you have langchain-core 0.2.3 which is incompatible.
# Successfully installed langchain-0.2.1 langchain-community-0.2.1 langchain-core-0.2.3 langchain-experimental-0.0.59 langchain-text-splitters-0.2.0 langsmith-0.1.67
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import OpenAI, SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain

from dotenv import load_dotenv

import os

load_dotenv()
OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')

db_user = "username"
db_password = "password"
db_host = "localhost"
db_name = "itanong"
db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")

llm = OpenAI(temperature=0)

db_chain = SQLDatabaseChain(llm=llm, database=db, verbose=True)

db_chain.run("What are the categories of the products?")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 15
#      13 db_host = "localhost"
#      14 db_name = "itanong"
# ---> 15 db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")
#      17 llm = OpenAI(temperature=0)
#      19 db_chain = SQLDatabaseChain(llm=llm, database=db, verbose=True)
#
# File ~/anaconda3/envs/itanong/lib/python3.11/site-packages/langchain_community/utilities/sql_database.py:135, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#     133 """Construct a SQLAlchemy engine from URI."""
#     134 _engine_args = engine_args or {}
# --> 135 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/anaconda3/envs/itanong/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/itanong/lib/python3.11/site-packages/sqlalchemy/engine/create.py:599, in create_engine(url, **kwargs)
#     597         if k in kwargs:
#     598             dbapi_args[k] = pop_kwarg(k)
# --> 599     dbapi = dbapi_meth(**dbapi_args)
#     601 dialect_args["dbapi"] = dbapi
#     603 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/anaconda3/envs/itanong/lib/python3.11/site-packages/sqlalchemy/dialects/mysql/pymysql.py:75, in MySQLDialect_pymysql.import_dbapi(cls)
#      73 @classmethod
#      74 def import_dbapi(cls):
# ---> 75     return __import__("pymysql")
#
# ModuleNotFoundError: No module named 'pymysql'
